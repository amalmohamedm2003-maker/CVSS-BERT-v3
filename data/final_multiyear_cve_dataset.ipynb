# %%
import pandas as pd
import numpy as np


data_2023 = pd.read_csv('C:\\Users\\ramee\\OneDrive\\Desktop\\cvss202223\\data\\cve_2023.csv')
data_2022 = pd.read_csv('C:\\Users\\ramee\\OneDrive\\Desktop\\cvss202223\\data\\cve_2022.csv')


print(data_2023.shape)
print(data_2022.shape)
# Out:
# (28797, 21)
# (25244, 21)

# %%
data = pd.concat([ data_2023, data_2022])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54041 entries, 0 to 25243
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 54041 non-null  object
#  1   lastModifiedDate              54041 non-null  object
#  2   CVE_ID                        54041 non-null  object
#  3   description                   54041 non-null  object
#  4   cvssV3_version                45716 non-null  float64
#  5   cvssV3_vectorString           45716 non-null  object
#  6   cvssV3_attackVector           45716 non-null  object
#  7   cvssV3_attackComplexity       45716 non-null  object
#  8   cvssV3_privilegesRequired     45716 non-null  object
#  9   cvssV3_userInteraction        45716 non-null  object
#  10  cvssV3_scope                  45716 non-null  object
#  11  cvssV3_confidentialityImpact  45716 non-null  object
# ...

# %%
data[["Description", "Product"]] = data["description"].str.split("Product:", expand=True)
data.drop(columns=['description'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54041 entries, 0 to 25243
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 54041 non-null  object
#  1   lastModifiedDate              54041 non-null  object
#  2   CVE_ID                        54041 non-null  object
#  3   cvssV3_version                45716 non-null  float64
#  4   cvssV3_vectorString           45716 non-null  object
#  5   cvssV3_attackVector           45716 non-null  object
#  6   cvssV3_attackComplexity       45716 non-null  object
#  7   cvssV3_privilegesRequired     45716 non-null  object
#  8   cvssV3_userInteraction        45716 non-null  object
#  9   cvssV3_scope                  45716 non-null  object
#  10  cvssV3_confidentialityImpact  45716 non-null  object
#  11  cvssV3_integrityImpact        45716 non-null  object
# ...

# %%
data.loc[data['cvssV3_baseSeverity'].isnull()]
# Out:
#            publishedDate   lastModifiedDate         CVE_ID  cvssV3_version  \
# 25     2023-06-21T17:15Z  2024-11-21T07:36Z  CVE-2023-0026             NaN
# 36     2023-01-03T15:15Z  2023-11-07T03:59Z  CVE-2023-0039             NaN
# 44     2023-01-27T23:15Z  2023-11-07T03:59Z  CVE-2023-0047             NaN
# 111    2023-02-01T07:15Z  2023-11-07T03:59Z  CVE-2023-0115             NaN
# 157    2023-01-11T08:15Z  2023-11-07T03:59Z  CVE-2023-0161             NaN
# ...                  ...                ...            ...             ...
# 25235  2024-04-09T19:15Z  2024-11-21T07:36Z  CVE-2022-4965             NaN
# 25236  2024-04-01T12:15Z  2024-11-21T07:36Z  CVE-2022-4966             NaN
# 25237  2024-05-14T11:57Z  2024-11-21T07:36Z  CVE-2022-4967             NaN
# 25239  2024-05-27T17:15Z  2024-11-21T07:36Z  CVE-2022-4969             NaN
# 25241  2024-10-16T07:15Z  2024-10-30T16:34Z  CVE-2022-4972             NaN
#
# ...

# %%
data['cvssV3_baseSeverity'].value_counts(dropna=False)
# Out:
# MEDIUM      19882
# HIGH        17529
# NaN          8325
# CRITICAL     7551
# LOW           754
# Name: cvssV3_baseSeverity, dtype: int64

# %%
for col_name in list(data.columns.values[5:13]):
    print(col_name)
    print( data[col_name].value_counts(dropna=False) )
# Out:
# cvssV3_attackVector
# NETWORK             34244
# LOCAL               10296
# NaN                  8325
# ADJACENT_NETWORK      771
# PHYSICAL              405
# Name: cvssV3_attackVector, dtype: int64
# cvssV3_attackComplexity
# LOW     44257
# NaN      8325
# HIGH     1459
# Name: cvssV3_attackComplexity, dtype: int64
# cvssV3_privilegesRequired
# NONE    25719
# LOW     15099
# NaN      8325
# HIGH     4898
# Name: cvssV3_privilegesRequired, dtype: int64
# cvssV3_userInteraction
# NONE        30557
# REQUIRED    15159
# NaN          8325
# Name: cvssV3_userInteraction, dtype: int64
# cvssV3_scope
# UNCHANGED    37004
# CHANGED       8712
# NaN           8325
# Name: cvssV3_scope, dtype: int64
# cvssV3_confidentialityImpact
# HIGH    26109
# LOW     10258
# NONE     9349
# NaN      8325
# Name: cvssV3_confidentialityImpact, dtype: int64
# cvssV3_integrityImpact
# HIGH    22103
# NONE    13516
# LOW     10097
# NaN      8325
# Name: cvssV3_integrityImpact, dtype: int64
# ...

# %%
data = data[data['cvssV3_baseSeverity'].notna()]
data.shape
# Out:
# (45716, 22)

# %%
for col_name in list(data.columns.values[5:13]):
    print(col_name)
    print( data[col_name].value_counts(dropna=False)/data.shape[0])
# Out:
# cvssV3_attackVector
# NETWORK             0.749059
# LOCAL               0.225217
# ADJACENT_NETWORK    0.016865
# PHYSICAL            0.008859
# Name: cvssV3_attackVector, dtype: float64
# cvssV3_attackComplexity
# LOW     0.968086
# HIGH    0.031914
# Name: cvssV3_attackComplexity, dtype: float64
# cvssV3_privilegesRequired
# NONE    0.562582
# LOW     0.330278
# HIGH    0.107140
# Name: cvssV3_privilegesRequired, dtype: float64
# cvssV3_userInteraction
# NONE        0.668409
# REQUIRED    0.331591
# Name: cvssV3_userInteraction, dtype: float64
# cvssV3_scope
# UNCHANGED    0.809432
# CHANGED      0.190568
# Name: cvssV3_scope, dtype: float64
# cvssV3_confidentialityImpact
# HIGH    0.571113
# LOW     0.224385
# NONE    0.204502
# Name: cvssV3_confidentialityImpact, dtype: float64
# cvssV3_integrityImpact
# HIGH    0.483485
# NONE    0.295651
# LOW     0.220864
# Name: cvssV3_integrityImpact, dtype: float64
# cvssV3_availabilityImpact
# HIGH    0.563413
# NONE    0.419569
# ...

# %%
data['cvssV3_baseSeverity'].value_counts(dropna=False)
# Out:
# MEDIUM      19882
# HIGH        17529
# CRITICAL     7551
# LOW           754
# Name: cvssV3_baseSeverity, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45716 entries, 0 to 25243
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 45716 non-null  object
#  1   lastModifiedDate              45716 non-null  object
#  2   CVE_ID                        45716 non-null  object
#  3   cvssV3_version                45716 non-null  float64
#  4   cvssV3_vectorString           45716 non-null  object
#  5   cvssV3_attackVector           45716 non-null  object
#  6   cvssV3_attackComplexity       45716 non-null  object
#  7   cvssV3_privilegesRequired     45716 non-null  object
#  8   cvssV3_userInteraction        45716 non-null  object
#  9   cvssV3_scope                  45716 non-null  object
#  10  cvssV3_confidentialityImpact  45716 non-null  object
#  11  cvssV3_integrityImpact        45716 non-null  object
# ...

# %%
data.to_csv('C:\\Users\\ramee\\OneDrive\\Desktop\\amal new data\\data\\cve_2022-2023_complete_dataset.csv', index=False)
